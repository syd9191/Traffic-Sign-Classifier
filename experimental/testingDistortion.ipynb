# %%
import os
import random
import numpy as np
from PIL import Image, ImageOps, ImageEnhance
import cv2
import matplotlib.pyplot as plt

# %%
gauss_noise = np.zeros_like(image, dtype=np.uint8)
cv2.randn(gauss_noise,128,20)
gauss_noise=(gauss_noise*0.5).astype(np.uint8)

# %%
image=cv2.imread("../experimental/data_classes/0/0_1335.png")
print(image.shape)
print(gauss_noise.shape)
gn_img=cv2.add(image, gauss_noise)
# Out:
# (247, 257, 3)
# (247, 257, 3)

# %%
fig = plt.figure(dpi=300)

fig.add_subplot(1, 3, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title("Original")

fig.add_subplot(1, 3, 2)
plt.imshow(cv2.cvtColor(gauss_noise, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title("Gaussian Noise")

fig.add_subplot(1, 3, 3)
plt.imshow(cv2.cvtColor(gn_img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title("Combined")

plt.tight_layout()
plt.show()
